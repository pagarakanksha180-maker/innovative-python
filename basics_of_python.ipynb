# %% [markdown]
# <a href="https://colab.research.google.com/github/pagarakanksha180-maker/innovative-python/blob/main/basics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.code to print largest number among three numbers

# %%
a=10
b=20
c=30
if a>b and a>c:
  print(a)
elif b>a and b>c:
  print(b)
else:
  print(c)
# Out:
# 30

# %% [markdown]
# 2. code to check positive number or not

# %%
a=int(input("Enter value of a"))
if a>0:
  print("positive")
else:
  print("Negative")
# Out:
# Enter value of a2
# positive

# %% [markdown]
# 3.code to find ASCII value of any character
#
# ---

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# 4.code to convert lowercase letter into uppercase letter using ASCII values

# %%
a=input()
print(chr(ord(a)-32))
# Out:
# e
# E

# %% [markdown]
# 5.code to convert lowercase character into uppercase equivalent using ASCII values (without using inbuilt string functions)

# %%
a=input()
b=ord(a)
R=chr(b-32)
print(R)
# Out:
# e
# E
